# %%
import pandas as pd
from sqlalchemy import create_engine, text
import configparser
import re

# Leer el archivo de configuración
config = configparser.ConfigParser()
config.read('../goodreads_config.cfg')

# Obtener las credenciales de la base de datos
db_user = config['database']['user']
db_password = config['database']['password']
db_host = config['database']['host']
db_name = config['database']['database']

# Crear conexión a la base de datos
engine = create_engine(f'mysql+pymysql://{db_user}:{db_password}@{db_host}/{db_name}')

# Leer tabla ""books"" de la base de datos
books = pd.read_sql_table('authors', engine)

books.describe(include='all').T
# Out:
#                       count  unique  \
# author_id          209517.0     NaN
# name                 209517  209500
# sex                 88544.0     NaN
# born                  31230     NaN
# died                  12488     NaN
# age                 11848.0     NaN
# original_hometown     44599   15137
# country               44599     215
# latitude            44369.0     NaN
# longitude           44369.0     NaN
# image_url            209517   84128
# website               58320   58003
# twitter               35122   35122
# workcount          209517.0     NaN
# influence              7882    7469
# genre                 73983    7781
# average_rate       209517.0     NaN
# rating_count       209517.0     NaN
# review_count       209517.0     NaN
# fan_count          209517.0     NaN
# about                 86724   85574
#
#                                                                  top    freq  \
# author_id                                                        NaN     NaN
# name                                                   داستان همشهری       2
# sex                                                              NaN     NaN
# born                                                             NaN     NaN
# died                                                             NaN     NaN
# age                                                              NaN     NaN
# original_hometown                                             London    1094
# country                                                United States   19444
# latitude                                                         NaN     NaN
# longitude                                                        NaN     NaN
# image_url          https://s.gr-assets.com/assets/nophoto/user/u_...  105049
# website            http://www.convilleandwalsh.com/index.php/auth...      13
# twitter                                                  LucySMarin1       1
# workcount                                                        NaN     NaN
# influence                  https://www.goodreads.com/author/show...,      55
# genre                                             fiction,literature    2020
# average_rate                                                     NaN     NaN
# rating_count                                                     NaN     NaN
# review_count                                                     NaN     NaN
# fan_count                                                        NaN     NaN
# about              <i>Librarian Note: There is more than one auth...     236
#
#                                             mean                  min  \
# author_id                         4694173.292081                  4.0
# name                                         NaN                  NaN
# sex                                     0.528359                  0.0
# born               1938-12-22 21:46:14.178674304  1680-01-01 00:00:00
# died               1976-12-01 22:14:36.361306848  1678-08-16 00:00:00
# age                                     72.13905              -89.013
# original_hometown                            NaN                  NaN
# country                                      NaN                  NaN
# latitude                               36.620498                -85.9
# longitude                             -29.873262           -176.64028
# image_url                                    NaN                  NaN
# website                                      NaN                  NaN
# twitter                                      NaN                  NaN
# workcount                              35.624818                  0.0
# influence                                    NaN                  NaN
# genre                                        NaN                  NaN
# average_rate                            3.861705                  0.0
# rating_count                         7236.301159                  0.0
# review_count                          514.567171                  0.0
# fan_count                             166.382189                -18.0
# about                                        NaN                  NaN
#
#                                    25%                  50%  \
# author_id                     309867.0            2892154.0
# name                               NaN                  NaN
# sex                                0.0                  1.0
# born               1923-10-25 00:00:00  1947-01-14 00:00:00
# died               1961-08-08 12:00:00  1993-05-01 12:00:00
# age                          62.528425             74.63385
# original_hometown                  NaN                  NaN
# country                            NaN                  NaN
# latitude                      34.27223             40.76843
# longitude                    -83.00018            -61.66667
# image_url                          NaN                  NaN
# website                            NaN                  NaN
# twitter                            NaN                  NaN
# workcount                          3.0                  8.0
# influence                          NaN                  NaN
# genre                              NaN                  NaN
# average_rate                      3.67                  3.9
# rating_count                      65.0                297.0
# review_count                       8.0                 37.0
# fan_count                          1.0                  6.0
# about                              NaN                  NaN
#
#                                    75%                  max             std
# author_id                    7074207.0           20178817.0  5404023.730993
# name                               NaN                  NaN             NaN
# sex                                1.0                  1.0        0.499198
# born               1965-03-13 12:00:00  2012-10-01 00:00:00             NaN
# died               2009-06-05 06:00:00  2020-12-30 00:00:00             NaN
# age                            84.0931             176.4271       16.468977
# original_hometown                  NaN                  NaN             NaN
# country                            NaN                  NaN             NaN
# latitude                      47.75355             80.68333       20.113294
# longitude                     10.92539            178.83142       68.471148
# image_url                          NaN                  NaN             NaN
# website                            NaN                  NaN             NaN
# twitter                            NaN                  NaN             NaN
# workcount                         21.0            1278643.0     2895.527173
# influence                          NaN                  NaN             NaN
# genre                              NaN                  NaN             NaN
# average_rate                      4.11                 8.07        0.459039
# rating_count                    1308.0           24511114.0   108875.741221
# review_count                     162.0             579250.0     4541.834223
# fan_count                         33.0             709826.0     3221.995738
# about                              NaN                  NaN             NaN
